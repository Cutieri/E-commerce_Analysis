# %%
import pandas as pd

# %%
path = r'E:\E-commerce Analysis\Data\raw\perfil_cliente.csv'

# %%
df = pd.read_csv(path, sep=';', encoding='latin1')

# %%
df.head(10)
# Out:
#                  customer_unique_id  quantidade_vendida  total_gasto  \
# 0  ea046dbb36d4b15b577065b530a08ec3                   1    69.320000
# 1  67d21c8bea9d6017d1b124d3879dd815                   1   133.279999
# 2  dcfbc32ae520bb179c3dd7a85d305452                   1   116.940002
# 3  fc19fe9ac733e36ff8227c29435c2030                   2   133.529997
# 4  b4b26faae91bc1b8f9458d29bc3c200c                   1   143.039993
# 5  610d3e47ad4921adc40aa9fd6bbeeaa5                   1   112.980003
# 6  c1a83a518dec21a938b5ca2a66e47ef0                   1   116.230003
# 7  ee301c76bd2b939da9740c6f5eb280c6                   1    72.779999
# 8  20a37002322179007fa568552bfac6f2                   1   127.919998
# 9  c3293e875ffb1116018edf76d24e52a2                   1   150.149994
#
#      flag_cliente
# 0  Não recorrente
# 1  Não recorrente
# 2  Não recorrente
# 3      Recorrente
# 4  Não recorrente
# 5  Não recorrente
# 6  Não recorrente
# 7  Não recorrente
# 8  Não recorrente
# ...

# %%
df.isnull().sum()
# Out:
# customer_unique_id    0
# quantidade_vendida    0
# total_gasto           0
# flag_cliente          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 96096 entries, 0 to 96095
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_unique_id  96096 non-null  str
#  1   quantidade_vendida  96096 non-null  int64
#  2   total_gasto         96096 non-null  float64
#  3   flag_cliente        96096 non-null  str
# dtypes: float64(1), int64(1), str(2)
# memory usage: 2.9 MB

# %%
df.to_csv(r"perfil_cliente_tratado.csv", index=False)
