# %%
import pandas as pd
import numpy as np

# %%
path = r'E:\E-commerce Analysis\Data\raw\perfil_cliente.csv'
df = pd.read_csv(path, sep=';', encoding='cp1252')

# %%
df.head()
# Out:
#                         customer_id  total_gasto  numero_pedidos  \
# 0  15f3f60c0575a9f2a7d5434f7b8a7692        60.85               1
# 1  5a3f73cc3e52ab64478beb5ce8756f4b       413.31               1
# 2  d68f9c633f9ab44265b54f3792fcbe71        93.80               1
# 3  454b89aa74cc3a41ac6a964e7f6c9e67       147.61               1
# 4  5a23a92261328e087c062a7c265b7862       137.00               1
#
#      flag_cliente
# 0  Não recorrente
# 1  Não recorrente
# 2  Não recorrente
# 3  Não recorrente
# 4  Não recorrente

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     99441 non-null  str
#  1   total_gasto     99441 non-null  float64
#  2   numero_pedidos  99441 non-null  int64
#  3   flag_cliente    99441 non-null  str
# dtypes: float64(1), int64(1), str(2)
# memory usage: 3.0 MB

# %%
df.isnull().sum()
# Out:
# customer_id       0
# total_gasto       0
# numero_pedidos    0
# flag_cliente      0
# dtype: int64

# %%
df['total_gasto'] = df['total_gasto'].replace(',', '.')
df['total_gasto'] = df['total_gasto'].round(2)
