# %%
import pandas as pd

# %%
path = r'E:\E-commerce Analysis\Data\raw\vendas_mensais.csv'

# %%
df = pd.read_csv(path, sep=';')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ano                 25 non-null     int64
#  1   mes                 25 non-null     int64
#  2   faturamento         25 non-null     float64
#  3   quantidade_pedidos  25 non-null     int64
# dtypes: float64(1), int64(3)
# memory usage: 932.0 bytes

# %%
df.head()
# Out:
#     ano  mes  faturamento  quantidade_pedidos
# 0  2016    9       252.24                   4
# 1  2016   10    59,090.48                 324
# 2  2016   12        19.62                   1
# 3  2017    1   138,488.04                 800
# 4  2017    2   291,908.01                1780

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
df.isnull().sum()
# Out:
# ano                   0
# mes                   0
# faturamento           0
# quantidade_pedidos    0
# dtype: int64
