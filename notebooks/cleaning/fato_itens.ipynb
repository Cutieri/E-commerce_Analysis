# %%
import pandas as pd
import numpy as np

# %%
path = r"E:\E-commerce Analysis\Data\raw\fato_itens.csv"

# %%
df = pd.read_csv (path, sep= ';')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   order_id                  112650 non-null  str
#  1   order_purchase_timestamp  112650 non-null  str
#  2   product_id                112650 non-null  str
#  3   product_category_name     111046 non-null  str
#  4   seller_id                 112650 non-null  str
#  5   price                     112650 non-null  float64
#  6   freight_value             112650 non-null  float64
# dtypes: float64(2), str(5)
# memory usage: 6.0 MB

# %%
df.head()
# Out:
#                            order_id order_purchase_timestamp  \
# 0  008fab5602c441d51f30b1464f5d4643      2017-02-22 10:37:41
# 1  016fbc333d66b414be541c6159576c40      2018-05-30 18:09:10
# 2  01835ef41c5ac66dd9ec6084fa1d0533      2017-05-11 21:36:10
# 3  01a75ac3dd000b7628a684be97c29234      2018-01-23 10:32:39
# 4  03720fdc92032ee4abd471d172006ab0      2018-08-05 21:34:54
#
#                          product_id  product_category_name  \
# 0  f23c48d81cd6a0c87f5c3b14aac68371           beleza_saude
# 1  b0cd550945da1de6eb9cb69595d540df          esporte_lazer
# 2  bbaef2eadf31fe3ea6702077398be06c             perfumaria
# 3  b5c114b11d53b6fd85a6a90790f0b479  utilidades_domesticas
# 4  dd2ca29c9d0f93d3b1d28d7d7ee3025c            moveis_sala
#
#                           seller_id  price  freight_value
# 0  ebd2d60905fb58271facef5596b620d3  49.99          15.56
# 1  6b243f80ed07b10f0e8aa0f21a205f3c  84.90          18.52
# 2  cc419e0650a3c5ba77189a1882b7556a  56.99          15.15
# ...

# %%
df['order_purchase_timestamp'] = df['order_purchase_timestamp'].astype('datetime64[ns]')
df['product_category_name'] = df['product_category_name'].astype('category')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   order_id                  112650 non-null  str
#  1   order_purchase_timestamp  112650 non-null  datetime64[ns]
#  2   product_id                112650 non-null  str
#  3   product_category_name     111046 non-null  category
#  4   seller_id                 112650 non-null  str
#  5   price                     112650 non-null  float64
#  6   freight_value             112650 non-null  float64
# dtypes: category(1), datetime64[ns](1), float64(2), str(3)
# memory usage: 5.3 MB

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                 order_id order_purchase_timestamp  \
# 10876   699b7692e65138e6874b4c6f42202974      2018-03-07 16:59:34
# 10912   9f2c6714edee90964b0b631c22a22448      2018-02-06 01:03:08
# 11249   7cf4d6735272dc5678263c8d9c1144d4      2017-09-27 21:30:35
# 11298   bbca89624572b1532cc19840d3ad81c8      2017-02-14 10:55:36
# 11478   c3d98859790f5ef3e0ec03a886506d35      2018-03-20 22:30:20
# ...                                  ...                      ...
# 112300  fc325d6bae67acedec72848583cc6d27      2018-07-18 16:50:53
# 112301  fc325d6bae67acedec72848583cc6d27      2018-07-18 16:50:53
# 112439  cfbc27fc3b0b3946a3dea53be0022108      2018-01-22 12:33:43
# 112461  eaa0211ae0667cb758713505ee149479      2017-08-21 12:27:20
# 112492  2d1cfcc5ed3232215b908e86ff33da61      2018-01-21 21:52:15
#
#                               product_id product_category_name  \
# 10876   c92a8559445ec8f63ecf90c7dd910b7d                   NaN
# ...

# %%
df['product_category_name'] = df['product_category_name'].cat.add_categories(['unknown'])
df['product_category_name'] = df['product_category_name'].fillna('unknown')

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [order_id, order_purchase_timestamp, product_id, product_category_name, seller_id, price, freight_value]
# Index: []

# %%
df.isnull().sum()
# Out:
# order_id                    0
# order_purchase_timestamp    0
# product_id                  0
# product_category_name       0
# seller_id                   0
# price                       0
# freight_value               0
# dtype: int64

# %%
df.head(10)
# Out:
#                            order_id order_purchase_timestamp  \
# 0  008fab5602c441d51f30b1464f5d4643      2017-02-22 10:37:41
# 1  016fbc333d66b414be541c6159576c40      2018-05-30 18:09:10
# 2  01835ef41c5ac66dd9ec6084fa1d0533      2017-05-11 21:36:10
# 3  01a75ac3dd000b7628a684be97c29234      2018-01-23 10:32:39
# 4  03720fdc92032ee4abd471d172006ab0      2018-08-05 21:34:54
# 5  04a59fe46fc5aa341da5378c195ed53c      2017-11-26 09:32:06
# 6  04b7738ad5fbb213eeb7a2145bea8242      2018-05-16 10:58:56
# 7  05d27719c66597da0628a53f6009ed67      2017-11-01 19:01:18
# 8  05d27719c66597da0628a53f6009ed67      2017-11-01 19:01:18
# 9  062d3e3b803bd3e569cf8c165602f8f4      2018-06-25 17:26:38
#
#                          product_id  product_category_name  \
# 0  f23c48d81cd6a0c87f5c3b14aac68371           beleza_saude
# 1  b0cd550945da1de6eb9cb69595d540df          esporte_lazer
# 2  bbaef2eadf31fe3ea6702077398be06c             perfumaria
# ...

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
df.head(10)
# Out:
#                            order_id order_purchase_timestamp  \
# 0  008fab5602c441d51f30b1464f5d4643      2017-02-22 10:37:41
# 1  016fbc333d66b414be541c6159576c40      2018-05-30 18:09:10
# 2  01835ef41c5ac66dd9ec6084fa1d0533      2017-05-11 21:36:10
# 3  01a75ac3dd000b7628a684be97c29234      2018-01-23 10:32:39
# 4  03720fdc92032ee4abd471d172006ab0      2018-08-05 21:34:54
# 5  04a59fe46fc5aa341da5378c195ed53c      2017-11-26 09:32:06
# 6  04b7738ad5fbb213eeb7a2145bea8242      2018-05-16 10:58:56
# 7  05d27719c66597da0628a53f6009ed67      2017-11-01 19:01:18
# 8  05d27719c66597da0628a53f6009ed67      2017-11-01 19:01:18
# 9  062d3e3b803bd3e569cf8c165602f8f4      2018-06-25 17:26:38
#
#                          product_id  product_category_name  \
# 0  f23c48d81cd6a0c87f5c3b14aac68371           beleza_saude
# 1  b0cd550945da1de6eb9cb69595d540df          esporte_lazer
# 2  bbaef2eadf31fe3ea6702077398be06c             perfumaria
# ...

# %%
df['total_payment'] = df['price'] + df['freight_value']
df.head(10)
# Out:
#                            order_id order_purchase_timestamp  \
# 0  008fab5602c441d51f30b1464f5d4643      2017-02-22 10:37:41
# 1  016fbc333d66b414be541c6159576c40      2018-05-30 18:09:10
# 2  01835ef41c5ac66dd9ec6084fa1d0533      2017-05-11 21:36:10
# 3  01a75ac3dd000b7628a684be97c29234      2018-01-23 10:32:39
# 4  03720fdc92032ee4abd471d172006ab0      2018-08-05 21:34:54
# 5  04a59fe46fc5aa341da5378c195ed53c      2017-11-26 09:32:06
# 6  04b7738ad5fbb213eeb7a2145bea8242      2018-05-16 10:58:56
# 7  05d27719c66597da0628a53f6009ed67      2017-11-01 19:01:18
# 8  05d27719c66597da0628a53f6009ed67      2017-11-01 19:01:18
# 9  062d3e3b803bd3e569cf8c165602f8f4      2018-06-25 17:26:38
#
#                          product_id  product_category_name  \
# 0  f23c48d81cd6a0c87f5c3b14aac68371           beleza_saude
# 1  b0cd550945da1de6eb9cb69595d540df          esporte_lazer
# 2  bbaef2eadf31fe3ea6702077398be06c             perfumaria
# ...

# %%
df.to_csv("fato_itens_tratada.csv", index=False)
