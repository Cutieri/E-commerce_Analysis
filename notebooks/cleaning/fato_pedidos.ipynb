# %%
import pandas as pd

# %%
path = r'E:\E-commerce Analysis\Data\raw\fato_pedidos.csv'

# %%
df = pd.read_csv(path, sep=';')

# %%
df.head(10)
# Out:
#                            order_id                       customer_id  \
# 0  5eca2113141f2c0e048b11bdcb7a0371  aa1fd99d3fa9ef872384623522665eb2
# 1  85be7c94bcd3f908fc877157ee21f755  54b307e9a6121f572faef4f220fbac3a
# 2  a0ce637ae9c3e3dedcf9dea3715b7331  a18e4956844fab232555e2bfd53eca5e
# 3  a082f140d70dd20b4e2d7538557b5946  5d8f7d35350a0802b7e4bea9671b132a
# 4  c152d21bf4fc58f89b8644af56cdc116  225c0949be781e5efb085b4dacb0a4a8
# 5  8d9c47d02bd99ae8d7dd151ededa9281  e3c7e245a96d7fa339fe6c16f8da4e90
# 6  a5b431090739891ac76875d9ad9bff23  b769ee1c67d0e4f3c5b0abe1a1b958d4
# 7  cc1cc1d6081f7f07a16cc1a3e4ba0b78  7117d38240c00f27406372087b55d1fc
# 8  f51e3c7f79d1e2c076acbb6af1588b95  3469ebe2f9aa5e08f1a85ecf20b549e0
# 9  fe642627ef34edffd9e897365f2d0449  41c81db0288d706cbb0937bddbea8f95
#
#   order_purchase_timestamp order_status customer_state  total_payment
# 0      2018-01-07 15:20:44    delivered             SP      41.169998
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   order_id                  99441 non-null  str
#  1   customer_id               99441 non-null  str
#  2   order_purchase_timestamp  99441 non-null  str
#  3   order_status              99441 non-null  str
#  4   customer_state            99441 non-null  str
#  5   total_payment             99441 non-null  float64
# dtypes: float64(1), str(5)
# memory usage: 4.6 MB

# %%
df['order_purchase_timestamp'] = df['order_purchase_timestamp'].astype('datetime64[ns]')

# %%
df.isnull().sum()
# Out:
# order_id                    0
# customer_id                 0
# order_purchase_timestamp    0
# order_status                0
# customer_state              0
# total_payment               0
# dtype: int64

# %%
df.to_csv("fato_pedidos_tratada.csv", index=False)
